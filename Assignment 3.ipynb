# %% [markdown]
# # Assignment 3
# ### D Gnana Sujith  21BCE9294

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds = pd.read_csv("Titanic.csv")
ds
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ds.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
ds.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
ds.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
ds.corr()
# Out:
# C:\Users\91949\AppData\Local\Temp\ipykernel_23428\2971842641.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ds.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# ...

# %%
sns.heatmap(ds.corr(),annot =True)
# Out:
# C:\Users\91949\AppData\Local\Temp\ipykernel_23428\3490597548.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ds.corr(),annot =True)
# <Axes: >

# %% [markdown]
# ## Checking for null values

# %%
ds.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
ds.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
mean_age = ds['Age'].mean()
mean_age = int(mean_age)
mean_age
# Out:
# 29

# %%
ds['Age'].replace(np.nan,mean_age,inplace=True)

# %%
ds['Age'] = ds['Age'].astype(int)

# %%
ds
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
ds['Cabin'].fillna('Unknown',inplace=True)
ds
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
mode_embarked = ds['Embarked'].mode()[0]
mode_embarked
# Out:
# 'S'

# %%
ds['Embarked'].fillna(mode_embarked,inplace=True)

# %%
ds.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
plt.hist(ds['Age'], bins=20, edgecolor='k')
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution')
plt.show()

# %%
pclass_counts = ds['Pclass'].value_counts()
plt.bar(pclass_counts.index, pclass_counts.values)
plt.xlabel('Pclass')
plt.ylabel('Count')
plt.title('Passenger Class Distribution')
plt.xticks(pclass_counts.index, labels=['1st', '2nd', '3rd'])
plt.show()

# %%
sns.boxplot(x='Pclass', y='Age', data=ds)
plt.xlabel('Pclass')
plt.ylabel('Age')
plt.title('Age Distribution by Passenger Class')
plt.show()

# %%
sns.countplot(x='Sex', data=ds)
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Passenger Gender Distribution')
plt.show()

# %%
sns.distplot(ds['Age'])
# Out:
# C:\Users\91949\AppData\Local\Temp\ipykernel_23428\3265561158.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ds['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int32
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(1), int32(1), int64(5), object(5)
# memory usage: 80.2+ KB

# %%
sns.countplot(x='Age',data=ds)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Embarked',data=ds)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.countplot(x='Sex',data=ds)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.jointplot(x='Embarked',y='Fare',data=ds)

# %%
sns.barplot(x='Embarked',y='Age',data=ds)
# Out:
# <Axes: xlabel='Embarked', ylabel='Age'>

# %%
sns.barplot(x='Embarked',y='Fare',data=ds)
# Out:
# <Axes: xlabel='Embarked', ylabel='Fare'>

# %%
sns.boxplot(x='Embarked',y='Fare',data=ds)
# Out:
# <Axes: xlabel='Embarked', ylabel='Fare'>

# %%
sns.boxplot(x='Embarked',y='Age',data=ds)
# Out:
# <Axes: xlabel='Embarked', ylabel='Age'>

# %%
ds.drop(["PassengerId","Name","Ticket","Cabin"],axis=1,inplace=True)
ds
# Out:
#      Survived  Pclass     Sex  Age  SibSp  Parch     Fare Embarked
# 0           0       3    male   22      1      0   7.2500        S
# 1           1       1  female   38      1      0  71.2833        C
# 2           1       3  female   26      0      0   7.9250        S
# 3           1       1  female   35      1      0  53.1000        S
# 4           0       3    male   35      0      0   8.0500        S
# ..        ...     ...     ...  ...    ...    ...      ...      ...
# 886         0       2    male   27      0      0  13.0000        S
# 887         1       1  female   19      0      0  30.0000        S
# 888         0       3  female   29      1      2  23.4500        S
# 889         1       1    male   26      0      0  30.0000        C
# 890         0       3    male   32      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %% [markdown]
# ## Outlier Detection

# %%
numerical_attributes = ds.select_dtypes(include=['int64', 'float64'])
plt.figure(figsize=(16, 8))  

for i, column in enumerate(numerical_attributes.columns):
    plt.subplot(2, 3, i+1) 
    sns.boxplot(x=column, data=numerical_attributes, whis=1.5) 

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Removal by IQR

# %%
# Define the numerical attributes
numerical_attributes = ['Age', 'SibSp', 'Parch', 'Fare']

# Define a function to detect and potentially remove outliers
def detect_and_remove_outliers(df, column):
    Q1 = ds[column].quantile(0.25)
    Q3 = ds[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = ds[(df[column] < lower_bound) | (ds[column] > upper_bound)]
    return outliers

# Detect and potentially remove outliers for each numerical attribute
outliers_dict = {}
for attribute in numerical_attributes:
    outliers = detect_and_remove_outliers(ds, attribute)
    outliers_dict[attribute] = outliers

# Print the detected outliers for each numerical attribute
for attribute, outliers in outliers_dict.items():
    print(f"Outliers in {attribute}:")
    print(outliers)

# Optionally, remove the outliers from the DataFrame
for attribute, outliers in outliers_dict.items():
    ds = ds[~ds.index.isin(outliers.index)]
# Out:
# Outliers in Age:
#      Survived  Pclass     Sex  Age  SibSp  Parch     Fare Embarked
# 7           0       3    male    2      3      1  21.0750        S
# 11          1       1  female   58      0      0  26.5500        S
# 15          1       2  female   55      0      0  16.0000        S
# 16          0       3    male    2      4      1  29.1250        Q
# 33          0       2    male   66      0      0  10.5000        S
# ..        ...     ...     ...  ...    ...    ...      ...      ...
# 827         1       2    male    1      0      2  37.0042        C
# 829         1       1  female   62      0      0  80.0000        S
# 831         1       2    male    0      1      1  18.7500        S
# 851         0       3    male   74      0      0   7.7750        S
# 879         1       1  female   56      0      1  83.1583        C
#
# [66 rows x 8 columns]
# Outliers in SibSp:
#      Survived  Pclass     Sex  Age  SibSp  Parch      Fare Embarked
# ...

# %% [markdown]
# ## Splitting of Dependent and Independent variables

# %%
X = ds.drop(columns='Survived',axis=1)
X
# Out:
#      Pclass     Sex  Age  SibSp  Parch     Fare Embarked
# 0         3    male   22      1      0   7.2500        S
# 2         3  female   26      0      0   7.9250        S
# 3         1  female   35      1      0  53.1000        S
# 4         3    male   35      0      0   8.0500        S
# 5         3    male   29      0      0   8.4583        Q
# ..      ...     ...  ...    ...    ...      ...      ...
# 884       3    male   25      0      0   7.0500        S
# 886       2    male   27      0      0  13.0000        S
# 887       1  female   19      0      0  30.0000        S
# 889       1    male   26      0      0  30.0000        C
# 890       3    male   32      0      0   7.7500        Q
#
# [577 rows x 7 columns]

# %%
X.shape
# Out:
# (577, 7)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
Y = ds['Survived']
Y
# Out:
# 0      0
# 2      1
# 3      1
# 4      0
# 5      0
#       ..
# 884    0
# 886    0
# 887    1
# 889    1
# 890    0
# Name: Survived, Length: 577, dtype: int64

# %%
type(Y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X['Sex'] = le.fit_transform(X['Sex'])
X
# Out:
#      Pclass  Sex  Age  SibSp  Parch     Fare Embarked
# 0         3    1   22      1      0   7.2500        S
# 2         3    0   26      0      0   7.9250        S
# 3         1    0   35      1      0  53.1000        S
# 4         3    1   35      0      0   8.0500        S
# 5         3    1   29      0      0   8.4583        Q
# ..      ...  ...  ...    ...    ...      ...      ...
# 884       3    1   25      0      0   7.0500        S
# 886       2    1   27      0      0  13.0000        S
# 887       1    0   19      0      0  30.0000        S
# 889       1    1   26      0      0  30.0000        C
# 890       3    1   32      0      0   7.7500        Q
#
# [577 rows x 7 columns]

# %%
Embarked=pd.get_dummies(X["Embarked"],drop_first=True)
Embarked
# Out:
#      Q  S
# 0    0  1
# 2    0  1
# 3    0  1
# 4    0  1
# 5    1  0
# ..  .. ..
# 884  0  1
# 886  0  1
# 887  0  1
# 889  0  0
# 890  1  0
#
# [577 rows x 2 columns]

# %%
X=pd.concat([X,Embarked],axis=1)
X.drop(["Embarked"],axis=1,inplace=True)
X.head()
# Out:
#    Pclass  Sex  Age  SibSp  Parch     Fare  Q  S
# 0       3    1   22      1      0   7.2500  0  1
# 2       3    0   26      0      0   7.9250  0  1
# 3       1    0   35      1      0  53.1000  0  1
# 4       3    1   35      0      0   8.0500  0  1
# 5       3    1   29      0      0   8.4583  1  0

# %%
from sklearn.preprocessing import MinMaxScaler
ms = MinMaxScaler()
X_Scaled = pd.DataFrame(ms.fit_transform(X),columns=X.columns)
X_Scaled.head()
# Out:
#    Pclass  Sex       Age  SibSp  Parch      Fare    Q    S
# 0     1.0  1.0  0.346939    0.5    0.0  0.118512  0.0  1.0
# 1     1.0  0.0  0.428571    0.0    0.0  0.129546  0.0  1.0
# 2     0.0  0.0  0.612245    0.5    0.0  0.868002  0.0  1.0
# 3     1.0  1.0  0.612245    0.0    0.0  0.131590  0.0  1.0
# 4     1.0  1.0  0.489796    0.0    0.0  0.138264  1.0  0.0

# %% [markdown]
# ## Splitting Data into Train and Test

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((461, 8), (116, 8), (461,), (116,))

# %% [markdown]
# ## Feauture Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[ 0.68718498, -1.77571201, -0.87538682, ..., -0.5975128 ,
#         -0.35269001,  0.58987559],
#        [ 0.68718498,  0.56315438,  0.99183504, ..., -0.54577872,
#         -0.35269001,  0.58987559],
#        [-0.67829897,  0.56315438,  0.52502957, ..., -0.13688884,
#         -0.35269001,  0.58987559],
#        ...,
#        [ 0.68718498,  0.56315438, -0.64198409, ...,  0.7563211 ,
#         -0.35269001,  0.58987559],
#        [ 0.68718498,  0.56315438, -0.05847726, ...,  0.68422343,
#          2.83535107, -1.69527272],
#        [-2.04378292,  0.56315438,  0.17492548, ...,  2.86684399,
#         -0.35269001,  0.58987559]])

# %%
x_test
# Out:
# array([[ 0.6437704 , -1.62018517, -0.57178736, -0.46429394,  0.        ,
#         -0.61674534, -0.35526552,  0.52414242],
#        [-2.07177021, -1.62018517, -0.08940675,  1.77979343,  0.        ,
#          2.78590165, -0.35526552,  0.52414242],
#        [ 0.6437704 ,  0.6172134 ,  1.71952053, -0.46429394,  0.        ,
#         -0.60520442, -0.35526552,  0.52414242],
#        [ 0.6437704 ,  0.6172134 , -1.65714373, -0.46429394,  0.        ,
#         -0.61674534, -0.35526552,  0.52414242],
#        [ 0.6437704 ,  0.6172134 ,  0.27237871, -0.46429394,  0.        ,
#         -0.60745105, -0.35526552,  0.52414242],
#        [-0.7139999 , -1.62018517,  1.71952053,  1.77979343,  0.        ,
#          0.78547606, -0.35526552,  0.52414242],
#        [-0.7139999 , -1.62018517, -0.08940675,  1.77979343,  0.        ,
#          0.78547606, -0.35526552,  0.52414242],
#        [ 0.6437704 ,  0.6172134 ,  1.84011569, -0.46429394,  0.        ,
#         -0.59558699, -0.35526552,  0.52414242],
# ...
